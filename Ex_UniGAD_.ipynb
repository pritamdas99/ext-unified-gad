# %%
# %cd /content
# !git clone https://github.com/pritamdas99/ext-unified-gad.git

# %%
# %cd ext-unified-gad
# %pwd

# %%
# Create required directory
# !mkdir -p datasets/csv

# %%
# download Bitcoin OTC dataset
# !wget https://snap.stanford.edu/data/soc-sign-bitcoinotc.csv.gz -O datasets/csv/soc-sign-bitcoinotc.csv.gz

# unzip it
# !gunzip -f datasets/csv/soc-sign-bitcoinotc.csv.gz

# verify
# !ls datasets/csv

# %%
# download Bitcoin Alpha dataset
# !wget https://snap.stanford.edu/data/soc-sign-bitcoinalpha.csv.gz -O datasets/csv/soc-sign-bitcoinalpha.csv.gz

# unzip it
# !gunzip -f datasets/csv/soc-sign-bitcoinalpha.csv.gz

# verify
# !ls datasets/csv

# %%
# download reddit hyperlinks (body)
# !wget https://snap.stanford.edu/data/soc-redditHyperlinks-body.tsv \
-O datasets/csv/soc-redditHyperlinks-body.tsv

# verify
# !ls datasets/csv

# %%
# !git fetch --all
# !git checkout main

# %%
# !git pull origin csv_dgl_conv

# %%
# %pwd

# %%
# %cat requirements.txt

# %%
# !pip uninstall -y dgl
# !pip install dgl==2.2.1+cu121 -f https://data.dgl.ai/wheels/torch-2.2/cu121/repo.html

# %%
# !pip install -r requirements.txt

# %%
# !pip install pyg_lib torch_scatter torch_sparse torch_cluster torch_spline_conv \
  -f https://data.pyg.org/whl/torch-2.2.1+cu121.html

# %%
import torch
print(torch.cuda.is_available())
print(torch.version.cuda)

# %%
# %cd /content/ext-unified-gad
# %cd src
# !ls

# %%
# !python main.py --datasets 22 --pretrain_model graphmae --kernels gcn --lr 5e-4 --save_model --epoch_pretrain 50 --batch_size 10 --khop 1 --epoch_ft 300 --lr_ft 0.003 --final_mlp_layers 3 --cross_modes ne2ne --metric AUROC --trials 5
